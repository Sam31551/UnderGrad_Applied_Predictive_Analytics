# %% [markdown]
# # Read in Data

# %%
#Read in previously cleaned data
import pandas as pd
data = pd.read_csv('final_clean_data.csv')
data.head()
# Out:
#    overall  potential    value_eur  wage_eur   age  height_cm  weight_kg  \
# 0     93.0       93.0   78000000.0  320000.0  34.0      170.0       72.0
# 1     92.0       92.0  119500000.0  270000.0  32.0      185.0       81.0
# 2     91.0       91.0   45000000.0  270000.0  36.0      187.0       83.0
# 3     91.0       91.0  129000000.0  270000.0  29.0      175.0       68.0
# 4     91.0       91.0  125500000.0  350000.0  30.0      181.0       70.0
#
#    club_team_id  league_level  club_position  ...  mentality_interceptions  \
# 0          73.0           1.0              0  ...                     40.0
# 1          21.0           1.0              0  ...                     49.0
# 2          11.0           1.0              0  ...                     29.0
# 3          73.0           1.0              0  ...                     37.0
# 4          10.0           1.0              2  ...                     66.0
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# ...

# %%
print(data.isnull().values.any())
# Out:
# False

# %%
data.columns[data.isna().any()].tolist()
# Out:
# []

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9847 entries, 0 to 9846
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   overall                      9847 non-null   float64
#  1   potential                    9847 non-null   float64
#  2   value_eur                    9847 non-null   float64
#  3   wage_eur                     9847 non-null   float64
#  4   age                          9847 non-null   float64
#  5   height_cm                    9847 non-null   float64
#  6   weight_kg                    9847 non-null   float64
#  7   club_team_id                 9847 non-null   float64
#  8   league_level                 9847 non-null   float64
#  9   club_position                9847 non-null   int64
#  10  club_contract_valid_until    9847 non-null   float64
#  11  preferred_foot               9847 non-null   int64
# ...

# %%
data.max()
# Out:
# overall                               93.0
# potential                             95.0
# value_eur                      194000000.0
# wage_eur                          350000.0
# age                                   39.0
# height_cm                            203.0
# weight_kg                            110.0
# club_team_id                      115820.0
# league_level                           5.0
# club_position                          3.0
# club_contract_valid_until           2031.0
# preferred_foot                         1.0
# weak_foot                              5.0
# skill_moves                            5.0
# international_reputation               5.0
# release_clause_eur             373500000.0
# pace                                  97.0
# shooting                              94.0
# passing                               93.0
# dribbling                             95.0
# defending                             91.0
# physic                                90.0
# ...

# %%
data.min()
# Out:
# overall                            64.0
# potential                          64.0
# value_eur                      100000.0
# wage_eur                          500.0
# age                                16.0
# height_cm                         156.0
# weight_kg                          53.0
# club_team_id                        1.0
# league_level                        1.0
# club_position                       0.0
# club_contract_valid_until        2021.0
# preferred_foot                      0.0
# weak_foot                           1.0
# skill_moves                         2.0
# international_reputation            1.0
# release_clause_eur             125000.0
# pace                               28.0
# shooting                           18.0
# passing                            33.0
# dribbling                          33.0
# defending                          16.0
# physic                             34.0
# attacking_crossing                 15.0
# ...

# %%
data.mean()
# Out:
# overall                        7.002965e+01
# potential                      7.290952e+01
# value_eur                      4.487583e+06
# wage_eur                       1.388271e+04
# age                            2.693165e+01
# height_cm                      1.806127e+02
# weight_kg                      7.488281e+01
# club_team_id                   4.472029e+04
# league_level                   1.263532e+00
# club_position                  2.032396e+00
# club_contract_valid_until      2.022943e+03
# preferred_foot                 7.374835e-01
# weak_foot                      3.086321e+00
# skill_moves                    2.689652e+00
# international_reputation       1.157916e+00
# release_clause_eur             8.467116e+06
# pace                           6.901787e+01
# shooting                       5.642439e+01
# passing                        6.169148e+01
# dribbling                      6.628608e+01
# defending                      5.552554e+01
# ...

# %%
data.std()
# Out:
# overall                        4.656507e+00
# potential                      5.538266e+00
# value_eur                      9.698453e+06
# wage_eur                       2.429731e+04
# age                            4.148241e+00
# height_cm                      6.561346e+00
# weight_kg                      6.748664e+00
# club_team_id                   5.334329e+04
# league_level                   5.849641e-01
# club_position                  1.047552e+00
# club_contract_valid_until      1.239848e+00
# preferred_foot                 4.400241e-01
# weak_foot                      6.715715e-01
# skill_moves                    6.716432e-01
# international_reputation       4.700496e-01
# release_clause_eur             1.871836e+07
# pace                           1.197593e+01
# shooting                       1.364959e+01
# passing                        8.726954e+00
# dribbling                      8.569056e+00
# defending                      1.621482e+01
# ...

# %%
data.median()
# Out:
# overall                             69.0
# potential                           72.0
# value_eur                      1700000.0
# wage_eur                          6000.0
# age                                 27.0
# height_cm                          180.0
# weight_kg                           75.0
# club_team_id                      1877.0
# league_level                         1.0
# club_position                        2.0
# club_contract_valid_until         2023.0
# preferred_foot                       1.0
# weak_foot                            3.0
# skill_moves                          3.0
# international_reputation             1.0
# release_clause_eur             3100000.0
# pace                                70.0
# shooting                            60.0
# passing                             62.0
# dribbling                           67.0
# defending                           62.0
# physic                              70.0
# attacking_crossing                  61.0
# ...

# %%
data.shape
# Out:
# (9847, 53)

# %%
data.describe()
# Out:
#            overall    potential     value_eur       wage_eur          age  \
# count  9847.000000  9847.000000  9.847000e+03    9847.000000  9847.000000
# mean     70.029654    72.909516  4.487583e+06   13882.710470    26.931654
# std       4.656507     5.538266  9.698453e+06   24297.314211     4.148241
# min      64.000000    64.000000  1.000000e+05     500.000000    16.000000
# 25%      66.000000    69.000000  1.000000e+06    3000.000000    24.000000
# 50%      69.000000    72.000000  1.700000e+06    6000.000000    27.000000
# 75%      73.000000    76.000000  3.300000e+06   15000.000000    30.000000
# max      93.000000    95.000000  1.940000e+08  350000.000000    39.000000
#
#          height_cm    weight_kg   club_team_id  league_level  club_position  \
# count  9847.000000  9847.000000    9847.000000   9847.000000    9847.000000
# mean    180.612674    74.882807   44720.293998      1.263532       2.032396
# ...

# %%
data.describe().T
# Out:
#                               count          mean           std       min  \
# overall                      9847.0  7.002965e+01  4.656507e+00      64.0
# potential                    9847.0  7.290952e+01  5.538266e+00      64.0
# value_eur                    9847.0  4.487583e+06  9.698453e+06  100000.0
# wage_eur                     9847.0  1.388271e+04  2.429731e+04     500.0
# age                          9847.0  2.693165e+01  4.148241e+00      16.0
# height_cm                    9847.0  1.806127e+02  6.561346e+00     156.0
# weight_kg                    9847.0  7.488281e+01  6.748664e+00      53.0
# club_team_id                 9847.0  4.472029e+04  5.334329e+04       1.0
# league_level                 9847.0  1.263532e+00  5.849641e-01       1.0
# club_position                9847.0  2.032396e+00  1.047552e+00       0.0
# club_contract_valid_until    9847.0  2.022943e+03  1.239848e+00    2021.0
# preferred_foot               9847.0  7.374835e-01  4.400241e-01       0.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x="variable", y="value", data=pd.melt(data))
plt.show()

# %%
# We can plot the histogram of all numeric features at the same time.
plt.figure()
data.hist(figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff3477565b0>,
# ...
#       dtype=object)

# %%
data.plot(kind='box', vert=False);

# %%
data.plot(kind='box');

# %%
df1 = data.iloc[:,1:10]
df1.head()
# Out:
#    potential    value_eur  wage_eur   age  height_cm  weight_kg  club_team_id  \
# 0       93.0   78000000.0  320000.0  34.0      170.0       72.0          73.0
# 1       92.0  119500000.0  270000.0  32.0      185.0       81.0          21.0
# 2       91.0   45000000.0  270000.0  36.0      187.0       83.0          11.0
# 3       91.0  129000000.0  270000.0  29.0      175.0       68.0          73.0
# 4       91.0  125500000.0  350000.0  30.0      181.0       70.0          10.0
#
#    league_level  club_position
# 0           1.0              0
# 1           1.0              0
# 2           1.0              0
# 3           1.0              0
# 4           1.0              2

# %%
df2 = data.iloc[:,10:20]
df2.head()
# Out:
#    club_contract_valid_until  preferred_foot  weak_foot  skill_moves  \
# 0                     2023.0               0        4.0          4.0
# 1                     2023.0               1        4.0          4.0
# 2                     2023.0               1        4.0          5.0
# 3                     2025.0               1        5.0          5.0
# 4                     2025.0               1        5.0          4.0
#
#    international_reputation  release_clause_eur  pace  shooting  passing  \
# 0                       5.0         144300000.0  85.0      92.0     91.0
# 1                       5.0         197200000.0  78.0      92.0     79.0
# 2                       5.0          83300000.0  87.0      94.0     80.0
# 3                       5.0         238700000.0  91.0      83.0     86.0
# 4                       4.0         232200000.0  76.0      86.0     93.0
#
#    dribbling
# 0       95.0
# 1       86.0
# 2       88.0
# 3       94.0
# 4       88.0

# %%
df3 = data.iloc[:,20:30]
df3.head()
# Out:
#    defending  physic  attacking_crossing  attacking_finishing  \
# 0       34.0    65.0                85.0                 95.0
# 1       44.0    82.0                71.0                 95.0
# 2       34.0    75.0                87.0                 95.0
# 3       37.0    63.0                85.0                 83.0
# 4       64.0    78.0                94.0                 82.0
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                        70.0                     91.0               88.0
# 1                        90.0                     85.0               89.0
# 2                        90.0                     80.0               86.0
# 3                        63.0                     86.0               86.0
# 4                        55.0                     94.0               82.0
#
#    skill_dribbling  skill_curve  skill_fk_accuracy
# 0             96.0         93.0               94.0
# ...

# %%
df4 = data.iloc[:,30:40]
df4.head()
# Out:
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                91.0                96.0                   91.0
# 1                70.0                88.0                   77.0
# 2                77.0                88.0                   85.0
# 3                81.0                95.0                   93.0
# 4                93.0                91.0                   76.0
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                   80.0              91.0                94.0
# 1                   79.0              77.0                93.0
# 2                   88.0              86.0                94.0
# 3                   89.0              96.0                89.0
# 4                   76.0              79.0                91.0
#
#    movement_balance  power_shot_power  power_jumping  power_stamina
# 0              95.0              86.0           68.0           72.0
# ...

# %%
df5 = data.iloc[:,40:54]
df5.head()
# Out:
#    power_strength  power_long_shots  mentality_aggression  \
# 0            69.0              94.0                  44.0
# 1            86.0              87.0                  81.0
# 2            77.0              93.0                  63.0
# 3            53.0              81.0                  63.0
# 4            74.0              91.0                  76.0
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                     40.0                   93.0              95.0
# 1                     49.0                   95.0              81.0
# 2                     29.0                   95.0              76.0
# 3                     37.0                   86.0              90.0
# 4                     66.0                   88.0              94.0
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# 0                 75.0                 96.0                         20.0
# ...

# %%
#Creating subplot of each column with its own scale
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

fig, axs = plt.subplots(1, len(df1.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df1.iloc[:,i], flierprops=red_circle)
    ax.set_title(df1.columns[i], fontsize=20, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.tight_layout()

# %%
#Creating subplot of each column with its own scale
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

fig, axs = plt.subplots(1, len(df2.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df2.iloc[:,i], flierprops=red_circle)
    ax.set_title(df2.columns[i], fontsize=10, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.tight_layout()

# %%
#Creating subplot of each column with its own scale
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

fig, axs = plt.subplots(1, len(df3.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df3.iloc[:,i], flierprops=red_circle)
    ax.set_title(df3.columns[i], fontsize=10, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.tight_layout()

# %%
#Creating subplot of each column with its own scale
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

fig, axs = plt.subplots(1, len(df4.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df4.iloc[:,i], flierprops=red_circle)
    ax.set_title(df4.columns[i], fontsize=10, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.tight_layout()

# %%
#Creating subplot of each column with its own scale
red_circle = dict(markerfacecolor='red', marker='o', markeredgecolor='white')

fig, axs = plt.subplots(1, len(df5.columns), figsize=(20,10))

for i, ax in enumerate(axs.flat):
    ax.boxplot(df5.iloc[:,i], flierprops=red_circle)
    ax.set_title(df5.columns[i], fontsize=10, fontweight='bold')
    ax.tick_params(axis='y', labelsize=14)
    
plt.tight_layout()

# %% [markdown]
# #Correlations

# %%
import pandas
corr_matrix = data.corr()
correlations = corr_matrix["value_eur"].sort_values(ascending=False)
print(correlations)
# Out:
# value_eur                      1.000000
# release_clause_eur             0.995164
# wage_eur                       0.819595
# overall                        0.710571
# international_reputation       0.621118
# potential                      0.619241
# movement_reactions             0.582502
# attacking_short_passing        0.491519
# skill_ball_control             0.481695
# mentality_composure            0.476589
# dribbling                      0.411565
# passing                        0.406297
# skill_dribbling                0.353573
# mentality_vision               0.331315
# skill_long_passing             0.327737
# skill_moves                    0.275599
# power_shot_power               0.270113
# skill_curve                    0.267011
# mentality_positioning          0.264981
# shooting                       0.263865
# attacking_crossing             0.253240
# club_contract_valid_until      0.248710
# attacking_volleys              0.247924
# ...

# %%
#Take top 10 values
import seaborn as sns
viz_df = data[['value_eur', 'release_clause_eur', 'wage_eur', 'international_reputation', 'overall', 'potential', 'movement_reactions', 'mentality_composure', 'skill_ball_control', 'attacking_short_passing']]
corr = viz_df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr.corr().style.background_gradient(cmap='tab20c')
# Out:
# <style type="text/css">
# #T_5b815_row0_col0, #T_5b815_row0_col1, #T_5b815_row1_col0, #T_5b815_row1_col1, #T_5b815_row2_col2, #T_5b815_row3_col3, #T_5b815_row4_col4, #T_5b815_row5_col5, #T_5b815_row6_col6, #T_5b815_row7_col7, #T_5b815_row8_col8, #T_5b815_row9_col9 {
#   background-color: #d9d9d9;
#   color: #000000;
# }
# #T_5b815_row0_col2, #T_5b815_row1_col2, #T_5b815_row2_col0, #T_5b815_row2_col1 {
#   background-color: #969696;
#   color: #f1f1f1;
# }
# #T_5b815_row0_col3, #T_5b815_row1_col3, #T_5b815_row3_col0, #T_5b815_row3_col1, #T_5b815_row4_col5, #T_5b815_row7_col8, #T_5b815_row8_col7 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_5b815_row0_col4, #T_5b815_row1_col4, #T_5b815_row8_col5, #T_5b815_row8_col6, #T_5b815_row9_col5 {
#   background-color: #e6550d;
#   color: #f1f1f1;
# }
# #T_5b815_row0_col5, #T_5b815_row4_col0, #T_5b815_row4_col1, #T_5b815_row6_col8 {
#   background-color: #31a354;
#   color: #f1f1f1;
# }
# ...

# %%
data_corr = data.corr()
sns.heatmap(data_corr)

# %%
data.corr().style.background_gradient(cmap='tab20c')
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # Pandas Profiling

# %%
#See Output file

# %% [markdown]
# ##EDA

# %%
#Univariate stats variables not of a range between 0-100
data['club_position'].value_counts()
# Out:
# 3    4523
# 2    2164
# 1    2116
# 0    1044
# Name: club_position, dtype: int64

# %%
data['league_level'].value_counts()
# Out:
# 1.0    7883
# 2.0    1426
# 3.0     450
# 4.0      83
# 5.0       5
# Name: league_level, dtype: int64

# %%
data['att_wr'].value_counts()
# Out:
# 2    5534
# 0    3734
# 1     579
# Name: att_wr, dtype: int64

# %%
data['def_wr'].value_counts()
# Out:
# 2    6420
# 0    2429
# 1     998
# Name: def_wr, dtype: int64

# %%
data['club_contract_valid_until'].value_counts()
# Out:
# 2022.0    3281
# 2023.0    2548
# 2024.0    2018
# 2021.0     914
# 2025.0     742
# 2026.0     331
# 2027.0      11
# 2028.0       1
# 2031.0       1
# Name: club_contract_valid_until, dtype: int64

# %%
data['international_reputation'].value_counts()
# Out:
# 1.0    8656
# 2.0     890
# 3.0     244
# 4.0      51
# 5.0       6
# Name: international_reputation, dtype: int64

# %%
data['weak_foot'].value_counts()
# Out:
# 3.0    6041
# 4.0    2018
# 2.0    1552
# 5.0     214
# 1.0      22
# Name: weak_foot, dtype: int64

# %%
data['skill_moves'].value_counts()
# Out:
# 3.0    4616
# 2.0    4170
# 4.0    1008
# 5.0      53
# Name: skill_moves, dtype: int64

# %% [markdown]
# Feature Engineering

# %%
data.rename(columns={"def_wr": "defending_wr", "att_wr": "attacking_wr"})
# Out:
#       overall  potential    value_eur  wage_eur   age  height_cm  weight_kg  \
# 0        93.0       93.0   78000000.0  320000.0  34.0      170.0       72.0
# 1        92.0       92.0  119500000.0  270000.0  32.0      185.0       81.0
# 2        91.0       91.0   45000000.0  270000.0  36.0      187.0       83.0
# 3        91.0       91.0  129000000.0  270000.0  29.0      175.0       68.0
# 4        91.0       91.0  125500000.0  350000.0  30.0      181.0       70.0
# ...       ...        ...          ...       ...   ...        ...        ...
# 9842     64.0       72.0    1300000.0    1000.0  22.0      181.0       72.0
# 9843     64.0       70.0     925000.0    2000.0  23.0      177.0       71.0
# 9844     64.0       69.0     875000.0    3000.0  24.0      163.0       59.0
# 9845     64.0       64.0     400000.0     500.0  31.0      180.0       83.0
# 9846     64.0       74.0    1300000.0    2000.0  22.0      187.0       68.0
#
# ...

# %%
#Average attacking stats 
att_data = data.loc[:,['att' in i for i in data.columns]]
att_data.head(2)
# Out:
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                85.0                 95.0                        70.0
# 1                71.0                 95.0                        90.0
#
#    attacking_short_passing  attacking_volleys  att_wr
# 0                     91.0               88.0       2
# 1                     85.0               89.0       0

# %%
att_data.drop('att_wr', inplace=True, axis=1)
att_data.head(2)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                85.0                 95.0                        70.0
# 1                71.0                 95.0                        90.0
#
#    attacking_short_passing  attacking_volleys
# 0                     91.0               88.0
# 1                     85.0               89.0

# %%
#Average defending stats
def_data = data.loc[:,['def' in i for i in data.columns]]
def_data.head(2)
# Out:
#    defending  defending_marking_awareness  defending_standing_tackle  \
# 0       34.0                         20.0                       35.0
# 1       44.0                         35.0                       42.0
#
#    defending_sliding_tackle  def_wr
# 0                      24.0       1
# 1                      19.0       2

# %%
def_data.drop('def_wr', inplace=True, axis=1)
def_data.head(2)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    defending  defending_marking_awareness  defending_standing_tackle  \
# 0       34.0                         20.0                       35.0
# 1       44.0                         35.0                       42.0
#
#    defending_sliding_tackle
# 0                      24.0
# 1                      19.0

# %%
#Average attacking stats
att_data['average_attack'] = att_data.mean(axis=1)
att_data.head(5)
# Out:
# <ipython-input-46-5fde1f7d1744>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   att_data['average_attack'] = att_data.mean(axis=1)
#    attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                85.0                 95.0                        70.0
# 1                71.0                 95.0                        90.0
# 2                87.0                 95.0                        90.0
# 3                85.0                 83.0                        63.0
# 4                94.0                 82.0                        55.0
#
#    attacking_short_passing  attacking_volleys  average_attack
# 0                     91.0               88.0            85.8
# ...

# %%
att_data
# Out:
#       attacking_crossing  attacking_finishing  attacking_heading_accuracy  \
# 0                   85.0                 95.0                        70.0
# 1                   71.0                 95.0                        90.0
# 2                   87.0                 95.0                        90.0
# 3                   85.0                 83.0                        63.0
# 4                   94.0                 82.0                        55.0
# ...                  ...                  ...                         ...
# 9842                61.0                 46.0                        47.0
# 9843                55.0                 59.0                        51.0
# 9844                65.0                 45.0                        27.0
# 9845                29.0                 19.0                        63.0
# 9846                49.0                 67.0                        59.0
#
#       attacking_short_passing  attacking_volleys  average_attack
# ...

# %%
#Average defending stats
def_data['average_defend'] = def_data.mean(axis=1)
def_data.head(5)
# Out:
# <ipython-input-48-ce8c9f2c1f41>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_data['average_defend'] = def_data.mean(axis=1)
#    defending  defending_marking_awareness  defending_standing_tackle  \
# 0       34.0                         20.0                       35.0
# 1       44.0                         35.0                       42.0
# 2       34.0                         24.0                       32.0
# 3       37.0                         35.0                       32.0
# 4       64.0                         68.0                       65.0
#
#    defending_sliding_tackle  average_defend
# 0                      24.0           28.25
# 1                      19.0           35.00
# ...

# %%
def_data
# Out:
#       defending  defending_marking_awareness  defending_standing_tackle  \
# 0          34.0                         20.0                       35.0
# 1          44.0                         35.0                       42.0
# 2          34.0                         24.0                       32.0
# 3          37.0                         35.0                       32.0
# 4          64.0                         68.0                       65.0
# ...         ...                          ...                        ...
# 9842       58.0                         59.0                       58.0
# 9843       59.0                         56.0                       64.0
# 9844       22.0                         17.0                       24.0
# 9845       68.0                         71.0                       70.0
# 9846       26.0                         21.0                       23.0
#
#       defending_sliding_tackle  average_defend
# 0                         24.0           28.25
# ...

# %% [markdown]
# Add new columns to dataset

# %%
avg_def = def_data['average_defend']
avg_def
# Out:
# 0       28.25
# 1       35.00
# 2       28.50
# 3       33.25
# 4       62.50
#         ...
# 9842    58.75
# 9843    60.25
# 9844    21.25
# 9845    69.25
# 9846    22.50
# Name: average_defend, Length: 9847, dtype: float64

# %%
avg_att = att_data['average_attack']
avg_att
# Out:
# 0       85.8
# 1       86.0
# 2       87.6
# 3       80.6
# 4       81.4
#         ...
# 9842    50.4
# 9843    54.4
# 9844    49.4
# 9845    41.0
# 9846    58.8
# Name: average_attack, Length: 9847, dtype: float64

# %%
data['Avg_Def'] = avg_def
data['Avg_Att'] = avg_att
data.head()
# Out:
#    overall  potential    value_eur  wage_eur   age  height_cm  weight_kg  \
# 0     93.0       93.0   78000000.0  320000.0  34.0      170.0       72.0
# 1     92.0       92.0  119500000.0  270000.0  32.0      185.0       81.0
# 2     91.0       91.0   45000000.0  270000.0  36.0      187.0       83.0
# 3     91.0       91.0  129000000.0  270000.0  29.0      175.0       68.0
# 4     91.0       91.0  125500000.0  350000.0  30.0      181.0       70.0
#
#    club_team_id  league_level  club_position  ...  mentality_vision  \
# 0          73.0           1.0              0  ...              95.0
# 1          21.0           1.0              0  ...              81.0
# 2          11.0           1.0              0  ...              76.0
# 3          73.0           1.0              0  ...              90.0
# 4          10.0           1.0              2  ...              94.0
#
#    mentality_penalties  mentality_composure  defending_marking_awareness  \
# ...

# %%
data.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
#        'weight_kg', 'club_team_id', 'league_level', 'club_position',
#        'club_contract_valid_until', 'preferred_foot', 'weak_foot',
#        'skill_moves', 'international_reputation', 'release_clause_eur', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
# ...

# %%
#Remove ids, league_level, encoded vars
#All remaining variables re scored 1-99
continous_variables = ['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
       'weight_kg', 'release_clause_eur', 'pace',
       'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle', 'Avg_Def', 'Avg_Att']

# %%
unscalable_data = data[['club_team_id', 'league_level', 'club_position',
       'club_contract_valid_until', 'preferred_foot', 'weak_foot',
       'skill_moves', 'international_reputation', 'att_wr',
       'def_wr',]]

# %%
scalable_data = data[['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
       'weight_kg', 'release_clause_eur', 'pace',
       'shooting', 'passing', 'dribbling', 'defending', 'physic',
       'attacking_crossing', 'attacking_finishing',
       'attacking_heading_accuracy', 'attacking_short_passing',
       'attacking_volleys', 'skill_dribbling', 'skill_curve',
       'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
       'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
       'movement_reactions', 'movement_balance', 'power_shot_power',
       'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
       'mentality_aggression', 'mentality_interceptions',
       'mentality_positioning', 'mentality_vision', 'mentality_penalties',
       'mentality_composure', 'defending_marking_awareness',
       'defending_standing_tackle', 'defending_sliding_tackle', 'Avg_Def', 'Avg_Att']]
scalable_data.head()
# Out:
#    overall  potential    value_eur  wage_eur   age  height_cm  weight_kg  \
# 0     93.0       93.0   78000000.0  320000.0  34.0      170.0       72.0
# 1     92.0       92.0  119500000.0  270000.0  32.0      185.0       81.0
# 2     91.0       91.0   45000000.0  270000.0  36.0      187.0       83.0
# 3     91.0       91.0  129000000.0  270000.0  29.0      175.0       68.0
# 4     91.0       91.0  125500000.0  350000.0  30.0      181.0       70.0
#
#    release_clause_eur  pace  shooting  ...  mentality_interceptions  \
# 0         144300000.0  85.0      92.0  ...                     40.0
# 1         197200000.0  78.0      92.0  ...                     49.0
# 2          83300000.0  87.0      94.0  ...                     29.0
# 3         238700000.0  91.0      83.0  ...                     37.0
# 4         232200000.0  76.0      86.0  ...                     66.0
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# ...

# %% [markdown]
# Feature Scaling

# %%
#Use MinMax Scaler as upper and lower bounds are known 
from sklearn.preprocessing import MinMaxScaler
minmaxsc = MinMaxScaler()

scaled_data = pd.DataFrame(minmaxsc.fit_transform(scalable_data.values), columns=scalable_data.columns, index=scalable_data.index)
scaled_data.head()
# Out:
#     overall  potential  value_eur  wage_eur       age  height_cm  weight_kg  \
# 0  1.000000   0.935484   0.401753  0.914163  0.782609   0.297872   0.333333
# 1  0.965517   0.903226   0.615781  0.771102  0.695652   0.617021   0.491228
# 2  0.931034   0.870968   0.231563  0.771102  0.869565   0.659574   0.526316
# 3  0.931034   0.870968   0.664776  0.771102  0.565217   0.404255   0.263158
# 4  0.931034   0.870968   0.646725  1.000000  0.608696   0.531915   0.298246
#
#    release_clause_eur      pace  shooting  ...  mentality_interceptions  \
# 0            0.386140  0.826087  0.973684  ...                 0.370370
# 1            0.527821  0.724638  0.973684  ...                 0.481481
# 2            0.222765  0.855072  1.000000  ...                 0.234568
# 3            0.638969  0.913043  0.855263  ...                 0.333333
# 4            0.621560  0.695652  0.894737  ...                 0.691358
#
#    mentality_positioning  mentality_vision  mentality_penalties  \
# ...

# %%
# Place the DataFrames side by side
horizontal_stack = pd.concat([scaled_data, unscalable_data, ], axis=1)
horizontal_stack.head()
# Out:
#     overall  potential  value_eur  wage_eur       age  height_cm  weight_kg  \
# 0  1.000000   0.935484   0.401753  0.914163  0.782609   0.297872   0.333333
# 1  0.965517   0.903226   0.615781  0.771102  0.695652   0.617021   0.491228
# 2  0.931034   0.870968   0.231563  0.771102  0.869565   0.659574   0.526316
# 3  0.931034   0.870968   0.664776  0.771102  0.565217   0.404255   0.263158
# 4  0.931034   0.870968   0.646725  1.000000  0.608696   0.531915   0.298246
#
#    release_clause_eur      pace  shooting  ...  club_team_id  league_level  \
# 0            0.386140  0.826087  0.973684  ...          73.0           1.0
# 1            0.527821  0.724638  0.973684  ...          21.0           1.0
# 2            0.222765  0.855072  1.000000  ...          11.0           1.0
# 3            0.638969  0.913043  0.855263  ...          73.0           1.0
# 4            0.621560  0.695652  0.894737  ...          10.0           1.0
#
# ...

# %%
horizontal_stack.columns
# Out:
# Index(['overall', 'potential', 'value_eur', 'wage_eur', 'age', 'height_cm',
#        'weight_kg', 'release_clause_eur', 'pace', 'shooting', 'passing',
#        'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle', 'Avg_Def',
# ...

# %% [markdown]
# #Final Scaled Dataset

# %%
data = horizontal_stack
data.head()
# Out:
#     overall  potential  value_eur  wage_eur       age  height_cm  weight_kg  \
# 0  1.000000   0.935484   0.401753  0.914163  0.782609   0.297872   0.333333
# 1  0.965517   0.903226   0.615781  0.771102  0.695652   0.617021   0.491228
# 2  0.931034   0.870968   0.231563  0.771102  0.869565   0.659574   0.526316
# 3  0.931034   0.870968   0.664776  0.771102  0.565217   0.404255   0.263158
# 4  0.931034   0.870968   0.646725  1.000000  0.608696   0.531915   0.298246
#
#    release_clause_eur      pace  shooting  ...  club_team_id  league_level  \
# 0            0.386140  0.826087  0.973684  ...          73.0           1.0
# 1            0.527821  0.724638  0.973684  ...          21.0           1.0
# 2            0.222765  0.855072  1.000000  ...          11.0           1.0
# 3            0.638969  0.913043  0.855263  ...          73.0           1.0
# 4            0.621560  0.695652  0.894737  ...          10.0           1.0
#
# ...

# %%
print(data.isnull().values.any())
# Out:
# False

# %%
data.columns[data.isna().any()].tolist()
# Out:
# []

# %%
from google.colab import files
data.to_csv('final_scaled_data.csv', index=None)
files.download("final_scaled_data.csv")
